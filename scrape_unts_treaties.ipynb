# %%
import sys, os
import urllib.request
import pandas as pd
import zipfile

# from utility.repository import WorldTreatyIndexRepository

# %run ./file_utility

# TODO Lägg nedladdade filer i en ZIP-fil
# Out:
#   File "<ipython-input-1-2d2c113876dc>", line 3
#     import pandas as pd%run ./file_utility
#                        ^
# SyntaxError: invalid syntax

# %%
treaties = [
    ('104394', 304, 'GERME', 'POLAND', '19001'),
    ('200785', 1048, 'FRANCE', 'IRAN', '10708'),
    ('103692', 259, 'GERME', 'USSR', '20571'),
    ('105560', 387, 'GERME', 'ROMANI', '21381'),
    ('105874', 409, 'GERME', 'HUNGAR', '21903'),
    ('106426', 448, 'CUBA', 'GERME', '22369'),
    ('102886', 213, 'INDIA', 'TURKEY', '18808'),
    ('107927', 545, 'CZECHO', 'GERME', '23656'),
    ('108051', 552, 'GERME', 'POLAND', '23656'),
    ('100701', 46, 'CZECHO', 'FRANCE', '16779'),
    ('100892', 68, 'BELGIU', 'FRANCE', '16855'),
    ('100493', 32, 'FRANCE', 'NETHER', '17125'),
    ('100181', 12, 'FRANCE', 'POLAND', '17217'),
    ('104622', 318, 'INDIA', 'JAPAN', '20757'),
    ('100182', 12, 'AUSTRI', 'FRANCE', '17241'),
    ('100990', 77, 'FRANCE', 'UK', '17594'),
    ('104635', 319, 'INDIA', 'POLAND', '20906'),
    ('104911', 342, 'INDIA', 'ROMANI', '20940'),
    ('110228', 712, 'BRAZIL', 'FRANCE', '17873'),
    ('126257', 88, 'FRANCE', 'ITALY', '18206'),
    ('105145', 359, 'CZECHO', 'INDIA', '21738'),
    ('105642', 392, 'INDIA', 'USSR', '21958'),
    ('126503', 89, 'FRANCE', 'COLOMB', '19206'),
    ('129982', 93, 'FRANCE', 'JAPAN', '19491'),
    ('105818', 404, 'INDIA', 'NORWAY', '22390'),
    ('107504', 519, 'HUNGAR', 'INDIA', '22735'),
    ('109955', 695, 'BULGAR', 'INDIA', '23062'),
    ('117574', 1128, 'FRANCE', 'LUXEMB', '19763'),
    ('117575', 1128, 'FRANCE', 'GERMW', '20020'),
    ('111093', 778, 'FRANCE', 'TUNISI', '21655'),
    ('105404', 377, 'FRANCE', 'ISRAEL', '21884'),
    ('111739', 821, 'FRANCE', 'CHAD', '22139'),
    ('111599', 814, 'FRANCE', 'CAFRI', '22141'),
    ('111752', 821, 'FRANCE', 'congo', '22143'),
    ('110636', 741, 'CAMERO', 'FRANCE', '22233'),
    ('111544', 811, 'FRANCE', 'BENIN', '22395'),
    ('111143', 782, 'FRANCE', 'BURKIN', '22395'),
    ('110718', 747, 'FRANCE', 'IVORYC', '22395'),
    ('129079', 92, 'FRANCE', 'NIGER', '22395'),
    ('113418', 942, 'FRANCE', 'MAURIT', '22451'),
    ('122839', 1353, 'FRANCE', 'GUINEA', '22491'),
    ('111557', 811, 'FRANCE', 'RWANDA', '22984'),
    ('111370', 798, 'FRANCE', 'BURUND', '23053'),
    ('110368', 722, 'FRANCE', 'TOGO', '23202'),
    ('111563', 812, 'FRANCE', 'ALGERI', '23307'),
    ('111380', 798, 'FRANCE', 'ZAIRE', '23362'),
    ('117928', 1142, 'FRANCE', 'AUSTRI', '23502'),
    ('109442', 659, 'CHAD', 'FRANCE', '23516'),
    ('100075', 6, 'BELGIU', 'UK', '16909'),
    ('100700', 46, 'CZECHO', 'UK', '17334'),
    ('100526', 34, 'NORWAY', 'UK', '17582'),
    ('110726', 747, 'CZECHO', 'FRANCE', '23646'),
    ('109080', 635, 'ARGENT', 'FRANCE', '23653'),
    ('101099', 82, 'NETHER', 'UK', '17721'),
    ('102431', 183, 'LUXEMB', 'UK', '18441'),
    ('102570', 190, 'GREECE', 'UK', '18900'),
    ('102238', 172, 'ITALY', 'UK', '18960'),
    ('102237', 172, 'AUSTRI', 'UK', '19340'),
    ('103766', 263, 'BELGIU', 'GERMW', '20722'),
    ('103125', 226, 'PORTUG', 'UK', '20047'),
    ('104530', 313, 'TURKEY', 'UK', '20526'),
    ('104928', 343, 'GERMW', 'UK', '21293'),
    ('105717', 398, 'IRAN', 'UK', '21676'),
    ('105339', 374, 'IRAQ', 'UK', '21898'),
    ('105971', 414, 'SPAIN', 'UK', '22109'),
    ('110528', 733, 'FRANCE', 'ROMANI', '23753'),
    ('108331', 573, 'FRANCE', 'USA', '23869'),
    ('112726', 888, 'BRAZIL', 'INDIA', '25104'),
    ('105966', 414, 'JAPAN', 'UK', '22253'),
    ('106797', 470, 'ARGENT', 'UK', '22451'),
    ('112361', 862, 'CANADA', 'FRANCE', '24063'),
    ('107834', 539, 'CAMERO', 'UK', '23243'),
    ('109033', 633, 'AFGHAN', 'UK', '23851'),
    ('109508', 668, 'ALGERI', 'FRANCE', '24205'),
    ('111918', 833, 'BRAZIL', 'GERMW', '25363'),
    ('109283', 649, 'ITALY', 'UK', '23986'),
    ('111284', 793, 'FRANCE', 'POLAND', '24247'),
    ('132119', 95, 'FRANCE', 'BOLIVI', '24253'),
    ('109284', 649, 'ITALY', 'UK', '23986'),
    ('109885', 690, 'FRANCE', 'INDIA', '24265'),
    ('105032', 351, 'UK', 'USSR', '21885'),
    ('105810', 404, 'UK', 'USSR', '22290'),
    ('106887', 475, 'UK', 'USSR', '23032'),
    ('107896', 543, 'UK', 'USSR', '23786'),
    ('107934', 545, 'UK', 'USA', '23872'),
    ('108337', 573, 'UK', 'YUGOSL', '24134'),
    ('111025', 772, 'FRANCE', 'HUNGAR', '24316'),
    ('109444', 659, 'EGYPT', 'UK', '24011'),
    ('109034', 633, 'KUWAIT', 'UK', '24437'),
    ('102750', 204, 'GERMW', 'USA', '19458'),
    ('110644', 741, 'ETHIOP', 'FRANCE', '24346'),
    ('112318', 859, 'AUSTRA', 'INDIA', '26227'),
    ('110645', 741, 'ETHIOP', 'FRANCE', '24346'),
    ('104626', 318, 'GERMW', 'JAPAN', '20865'),
    ('135899', 2071, 'GERMW', 'TURKEY', '20948'),
    ('128127', 91, 'BULGAR', 'FRANCE', '24395'),
    ('108785', 606, 'UK', 'USSR', '24527'),
    ('110898', 760, 'FRANCE', 'PANAMA', '24482'),
    ('112386', 863, 'UK', 'CHILE', '25155'),
    ('108754', 604, 'DENMAR', 'FRANCE', '24518'),
    ('109173', 642, 'FRANCE', 'ROMANI', '24649'),
    ('107095', 487, 'GERMW', 'NETHER', '22398'),
    ('111606', 815, 'FRANCE', 'CZECHO', '24771'),
    ('109880', 690, 'UK', 'USSR', '25290'),
    ('109291', 649, 'FRANCE', 'IRELAN', '24780'),
    ('111002', 771, 'FRANCE', 'TUNISI', '24828'),
    ('109530', 670, 'FRANCE', 'HONDUR', '24850'),
    ('110101', 704, 'FRANCE', 'EGYPT', '24916'),
    ('111298', 794, 'UK', 'USSR', '25994'),
    ('110386', 722, 'ISRAEL', 'UK', '25364'),
    ('10707', 2086, 'FRANCE', 'SPAIN', '25241'),
    ('110707', 746, 'FRANCE', 'SPAIN', '25241'),
    ('110316', 718, 'FRANCE', 'TUNISI', '25248'),
    ('110187', 709, 'ARGENT', 'FRANCE', '25283'),
    ('110739', 748, 'FRANCE', 'IRAQ', '25317'),
    ('110741', 748, 'COSTA', 'FRANCE', '25353'),
    ('110533', 733, 'FRANCE', 'ROMANI', '25379'),
    ('110742', 748, 'FRANCE', 'KUWAIT', '25464'),
    ('110737', 748, 'FRANCE', 'INDONE', '25466'),
    ('110461', 727, 'CYPRUS', 'FRANCE', '25505'),
    ('110743', 748, 'FRANCE', 'SUDAN', '25559'),
    ('111170', 784, 'BELGIU', 'FRANCE', '25583'),
    ('111289', 793, 'FRANCE', 'PORTUG', '25731'),
    ('113233', 930, 'FRANCE', 'MAURUS', '25741'),
    ('111561', 812, 'FRANCE', 'UGANDA', '25763'),
    ('122913', 1357, 'MEXICO', 'FRANCE', '25766'),
    ('110885', 759, 'FINLAN', 'FRANCE', '25822'),
    ('111005', 771, 'FRANCE', 'SRILAN', '25827'),
    ('111870', 830, 'FRANCE', 'KENYA', '26190'),
    ('127532', 90, 'GERMW', 'ITALY', '20493'),
    ('124345', 1437, 'FRANCE', 'SYRIA', '26192'),
    ('126274', 88, 'GERMW', 'GUINEA', '24799'),
    ('112292', 857, 'FRANCE', 'MOROCC', '26311'),
    ('111907', 832, 'FRANCE', 'EGYPT', '26369'),
    ('115884', 1054, 'FRANCE', 'PERU', '26387'),
    ('111908', 832, 'FRANCE', 'HAITI', '26408'),
    ('126263', 88, 'FRANCE', 'MALAYS', '26606')
]

# %%
sys.path.append(os.path.abspath(os.path.join('..')))



# 'https://treaties.un.org/doc/Publication/UNTS/Volume%20263/volume-263-I-3766-Other.pdf'

repository = WorldTreatyIndexRepository()

languages = [ ('English', 'en'), ('French', 'fr'), ('Other', 'other') ]

url_template = 'https://treaties.un.org/doc/Publication/UNTS/Volume%20{0}/{1}'
filename_template = 'volume-{0}-{3}-{1}-{2}.pdf'

result = pd.DataFrame(columns=['treaty_id', 'volume', 'party1', 'party2', 'signed', 'language', 'http_code', 'filename', 'status', 'url'])

for (treaty_id, volume, party1, party2, signed) in treaties:

    for (language, lang) in languages:

        for filename in [ filename_template.format(volume, int(str(treaty_id)[-5:]), language, 'I'),filename_template.format(volume, int(str(treaty_id)[-5:]), language, 'II') ]:

            url = url_template.format(volume, filename)
            status = False
            code = 0
            try:
                response = urllib.request.urlopen(url)
                code = response.getcode()
                status = code in [ 200 ]
                if status:
                    pdf = response.read()
                    savename = "{}-{}.pdf".format(treaty_id, lang)
                    path = repository.data_path(savename)
                    with open(path,'wb') as output:
                        output.write(pdf)
                    break

            except Exception as ex:
                #print(str(ex))
                status = False

        print('{}/{};{};{};{}'.format(volume, treaty_id, language, status, url))

        result = result.append({
                'treaty_id' : treaty_id,
                'volume' : volume,
                'party1': party1,
                'party2': party2,
                'signed': signed,
                'language': language,
                'http_code': code,
                'filename': filename,
                'status': status,
                'url': url
        }, ignore_index=True)

save_path = repository.data_path('UNTS-download-log.xlsx')
repository.save_excel([(result, 'Data')], save_path)
